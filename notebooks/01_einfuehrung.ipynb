# %% [markdown]
# # 01 Einfuehrung: KI/ML und Python\n
# \n
# Ziel: Erste Python-Schritte, Grundbegriffe KI/ML, kleine Datenanalyse.

# %%
import pandas as pd\n
\n
begriffe = {\n
    'KI': 'Systeme loesen Aufgaben, die intelligentes Verhalten erfordern',\n
    'Machine Learning': 'Modelle lernen Muster aus Daten',\n
    'Deep Learning': 'ML mit mehrschichtigen neuronalen Netzen'\n
}\n
for k, v in begriffe.items():\n
    print(f'{k}: {v}')

# %% [markdown]
# ## Erste Datenoperation

# %%
preise = [180000, 240000, 380000, 130000]\n
durchschnitt = sum(preise) / len(preise)\n
print('Durchschnittspreis:', round(durchschnitt, 2))

# %%
df = pd.read_csv('daten/haeuser.csv')\n
df.head()

# %% [markdown]
# ## Reflexion\n
# - Welche Teile waren regelbasiert?\n
# - Welche Teile waren datenbasiert?\n
# - Wo koennte KI im BWL-Kontext helfen?
